# %% [markdown]
# ## Analysis of Cas13a guides
# by Duo peng

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import re
from pathlib import Path

# %% [markdown]
# ## Read the guides table

# %%
guide_table = Path.cwd() / "guides_table.tsv"
df_guides = pd.read_csv(guide_table, sep='\t', header=None)
# Out:
# C:\Users\duo.peng\AppData\Local\Temp\ipykernel_24400\657589338.py:2: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_guides = pd.read_csv(guide_table, sep='\t', header=None)

# %%
df_guides.columns = ["segment (from sequence desc.)", 'guide', 'segment:targeted_variant_count',"subtype_targeted_count", "strain_targeted_count", "sequenceID (bvbrc)","start","target","spacer","strand","GC_content","A_content"]

#remove rows where guides are invalid
df_guides.drop(df_guides[(df_guides['guide'] == "nnnnnnnnnnnnnnnnnnnn") | (df_guides['guide'] == "aaaaaaaaaaaaaaaaaaaa") | (df_guides['guide'] == "target")].index, inplace=True)

df_guides["segment (from sequence desc.)"] = df_guides["segment (from sequence desc.)"].fillna(0).astype(int).astype(str)
df_guides["segment (from sequence desc.)"].replace("0", np.nan, inplace=True)

df_guides["segment:targeted_variant_count"] = df_guides["segment:targeted_variant_count"].fillna(pd.NA)

#remove rows where segment is invalid
#df_guides.dropna(subset=["segment"], inplace=True)

#reindex
df_guides.reset_index(drop=True, inplace=True)

# %%
pd.isna(df_guides.iloc[14249235]['segment:targeted_variant_count'])
# Out:
# True

# %% [markdown]
# compute total segment variants targeted by each guide

# %%
def compute_total_seg_targeted(input_string):
    if pd.isna(input_string):
        return 0
    pairs = input_string.split("|")
    total = 0
    for pair in pairs:
        if pair != ":":
            key, value = pair.split(":")
            total += int(value)
    return total

df_guides.insert(3, "total_count_targeted_segment", 
                df_guides["segment:targeted_variant_count"].apply(compute_total_seg_targeted))

# %%
df_guides
# Out:
#          segment (from sequence desc.)                 guide  \
# 0                                    6  aacagcttcgaacagataac
# 1                                    6  acagaaaacagcttcgaaca
# 2                                    6  ttcgaacagataacgtttat
# 3                                    6  tcgaacagataacgtttatg
# 4                                    6  cgaacagataacgtttatgc
# ...                                ...                   ...
# 14249231                           NaN  tgacaataatgtattgtccc
# 14249232                           NaN  gacaataatgtattgtccct
# 14249233                           NaN  acaataatgtattgtccctg
# 14249234                           NaN  caataatgtattgtccctga
# 14249235                           NaN  aataatgtattgtccctgag
#
#          segment:targeted_variant_count  total_count_targeted_segment  \
# 0                             6:9|8:886                           895
# 1                             6:9|8:786                           795
# 2                             6:9|8:771                           780
# 3                             6:9|8:771                           780
# 4                             6:9|8:771                           780
# ...                                 ...                           ...
# 14249231                            NaN                             0
# 14249232                            NaN                             0
# 14249233                            NaN                             0
# 14249234                            NaN                             0
# 14249235                            NaN                             0
#
#           subtype_targeted_count  strain_targeted_count sequenceID (bvbrc)  \
# 0                             23                    287           CY164524
# 1                              7                    144           CY146648
# 2                             25                    311           CY164524
# 3                             25                    310           CY164524
# 4                             25                    310           CY164524
# ...                          ...                    ...                ...
# 14249231                       0                      1           CY155150
# 14249232                       0                      1           CY155150
# 14249233                       0                      1           CY155150
# 14249234                       0                      1           CY155150
# 14249235                       0                      1           CY155150
#
#           start                target                spacer strand  \
# 0           760  aacagcttcgaacagataac  guuaucuguucgaagcuguu      +
# 1           725  acagaaaacagcttcgaaca  uguucgaagcuguuuucugu      +
# 2           766  ttcgaacagataacgtttat  auaaacguuaucuguucgaa      +
# 3           767  tcgaacagataacgtttatg  cauaaacguuaucuguucga      +
# 4           768  cgaacagataacgtttatgc  gcauaaacguuaucuguucg      +
# ...         ...                   ...                   ...    ...
# 14249231    540  tgacaataatgtattgtccc  gggacaauacauuauuguca      +
# 14249232    541  gacaataatgtattgtccct  agggacaauacauuauuguc      +
# 14249233    542  acaataatgtattgtccctg  cagggacaauacauuauugu      +
# 14249234    543  caataatgtattgtccctga  ucagggacaauacauuauug      +
# 14249235    544  aataatgtattgtccctgag  cucagggacaauacauuauu      +
#
#           GC_content  A_content
# 0               0.73       0.15
# 1               0.80       0.10
# 2               0.46       0.35
# 3               0.54       0.30
# 4               0.62       0.25
# ...              ...        ...
# 14249231        0.50       0.35
# 14249232        0.50       0.35
# 14249233        0.50       0.35
# 14249234        0.50       0.35
# 14249235        0.50       0.35
#
# [14249236 rows x 13 columns]

# %%
df_guides.to_csv(Path.cwd() / "guides_table_parsed.tsv", index=False, sep="\t")

# %%
# sort by strain_targeted_count
df_guides.sort_values(by=['strain_targeted_count'], inplace=True, ascending=False)

# %%
df_guides
# Out:
#          segment (from sequence desc.)                 guide  \
# 2420529                              6  tcaggccccctcaaagccga
# 10379293                             7  tcaggccccctcaaagccga
# 12786183                           NaN  tcaggccccctcaaagccga
# 4568103                              1  tcaggccccctcaaagccga
# 5946158                              4  tcaggccccctcaaagccga
# ...                                ...                   ...
# 6269992                              4  agtgtggtagaaactagaat
# 6269993                              4  tgtggtagaaactagaatta
# 6270031                              4  tggccaaaatgtacaagcag
# 6270032                              4  ggccaaaatgtacaagcagt
# 14249235                           NaN  aataatgtattgtccctgag
#
#          segment:targeted_variant_count  total_count_targeted_segment  \
# 2420529                4:1|6:13|7:32075                         32089
# 10379293          7:103096|4:4|6:13|1:1                        103114
# 12786183    7:4527808|4:372|6:1090|1:51                       4529321
# 4568103                     1:1|7:10490                         10491
# 5946158                 4:4|7:18644|6:5                         18653
# ...                                 ...                           ...
# 6269992                            4:32                            32
# 6269993                            4:32                            32
# 6270031                            4:32                            32
# 6270032                            4:32                            32
# 14249235                           <NA>                             0
#
#           subtype_targeted_count  strain_targeted_count sequenceID (bvbrc)  \
# 2420529                       72                   8932           CY129919
# 10379293                      72                   8932           CY129919
# 12786183                      72                   8932           CY129919
# 4568103                       72                   8932           CY129919
# 5946158                       72                   8932           CY129919
# ...                          ...                    ...                ...
# 6269992                        0                      1           KP766653
# 6269993                        0                      1           KP766653
# 6270031                        0                      1           KP766655
# 6270032                        0                      1           KP766655
# 14249235                       0                      1           CY155150
#
#           start                target                spacer strand  \
# 2420529      63  tcaggccccctcaaagccga  ucggcuuugagggggccuga      +
# 10379293     63  tcaggccccctcaaagccga  ucggcuuugagggggccuga      +
# 12786183     63  tcaggccccctcaaagccga  ucggcuuugagggggccuga      +
# 4568103      63  tcaggccccctcaaagccga  ucggcuuugagggggccuga      +
# 5946158      63  tcaggccccctcaaagccga  ucggcuuugagggggccuga      +
# ...         ...                   ...                   ...    ...
# 6269992    1225  agtgtggtagaaactagaat  auucuaguuucuaccacacu      +
# 6269993    1227  tgtggtagaaactagaatta  uaauucuaguuucuaccaca      +
# 6270031    1181  tggccaaaatgtacaagcag  cugcuuguacauuuuggcca      +
# 6270032    1182  ggccaaaatgtacaagcagt  acugcuuguacauuuuggcc      +
# 14249235    544  aataatgtattgtccctgag  cucagggacaauacauuauu      +
#
#           GC_content  A_content
# 2420529         0.87       0.10
# 10379293        0.87       0.10
# 12786183        0.87       0.10
# 4568103         0.87       0.10
# 5946158         0.87       0.10
# ...              ...        ...
# 6269992         0.58       0.25
# 6269993         0.50       0.30
# 6270031         0.75       0.15
# 6270032         0.75       0.15
# 14249235        0.50       0.35
#
# [14249236 rows x 13 columns]
